# %%
#J4.8 Decision Tree
import pandas as pd
from sklearn.model_selection import KFold, cross_val_score
from sklearn import tree
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

data=pd.read_csv("C:/Users/deepa/College_Lap_Back/kdd final prj/Results/q_weka.csv",sep=",")
#data=data[data.Class=="P"]
start_time = time.time()
k_fold = KFold(n_splits=10)
clf = tree.DecisionTreeClassifier(criterion='entropy')
scr=[]
prediction=[]
precision=[]
roc=[]
score=[]
probability=[]
confusion=[]

for traindata, testdata in k_fold.split(data):
    clf.fit(data.iloc[traindata,0:45],data.iloc[traindata,45])
    x=clf.predict(data.iloc[testdata,0:45])
    score.append(clf.score(data.iloc[testdata,0:45],data.iloc[testdata,45]))
    probability.append(clf.predict_proba(data.iloc[testdata,0:45]))
    precision.append(precision_score(data.iloc[testdata,45],x,average='weighted'))
    confusion.append(confusion_matrix(data.iloc[testdata,45], x))
    scr.append(clf.score(data.iloc[testdata,0:45],data.iloc[testdata,45]))
print(probability)
clf.feature_importances_

with open("C:/Users/deepa/College_Lap_Back/kdd final prj/Results/tree.dot", 'w') as f:
     f = tree.export_graphviz(clf,max_depth=4, out_file=f,feature_names=data.columns[0:45],class_names=["open_ended","yes_no"]) 
tree=clf.tree_
tree.capacity
sumconfusion=sum(confusion)
print('recall=',(float(sumconfusion[0][0])/float((sumconfusion[0][0]+sumconfusion[0][1]))+float(sumconfusion[1][1])/float((sumconfusion[1][1]+sumconfusion[1][0])))/2)
print('precision=' , (sum(precision)/10))
print('scr=' , (sum(scr)/10))
print('score=',(sum(score)/10))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [array([[ 0.49385189,  0.50614811],
#        [ 0.49385189,  0.50614811],
#        [ 0.49385189,  0.50614811],
#        ...,
#        [ 0.49385189,  0.50614811],
#        [ 0.75994318,  0.24005682],
#        [ 0.49385189,  0.50614811]]), array([[ 0.77793904,  0.22206096],
#        [ 0.49380237,  0.50619763],
#        [ 0.77793904,  0.22206096],
#        ...,
#        [ 0.49380237,  0.50619763],
#        [ 0.49380237,  0.50619763],
#        [ 0.49380237,  0.50619763]]), array([[ 0.49204703,  0.50795297],
#        [ 0.75862069,  0.24137931],
#        [ 0.49204703,  0.50795297],
#        ...,
#        [ 0.49204703,  0.50795297],
#        [ 0.49204703,  0.50795297],
#        [ 0.49204703,  0.50795297]]), array([[ 0.49427665,  0.50572335],
#        [ 0.49427665,  0.50572335],
#        [ 0.49427665,  0.50572335],
#        ...,
#        [ 0.49427665,  0.50572335],
#        [ 0.78512397,  0.21487603],
#        [ 0.49427665,  0.50572335]]), array([[ 0.49360879,  0.50639121],
# ...

# %%
#J4.8 Summary
import pandas as pd
from sklearn.model_selection import KFold, cross_val_score
from sklearn import tree
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

data=pd.read_csv("C:\Users\deepa\College_Lap_Back\weka_shower\Shower_weka.csv",sep=",")
#data=data[data.Class=="P"]
start_time = time.time()
k_fold = KFold(n_splits=10)
clf = tree.DecisionTreeClassifier(criterion='entropy')
scr=[]
prediction=[]
precision=[]
roc=[]
score=[]
probability=[]
confusion=[]

for traindata, testdata in k_fold.split(data):
    clf.fit(data.iloc[traindata,0:30],data.iloc[traindata,30])
    x=clf.predict(data.iloc[testdata,0:30])
    score.append(clf.score(data.iloc[testdata,0:30],data.iloc[testdata,30]))
    probability.append(clf.predict_proba(data.iloc[testdata,0:30]))
    precision.append(precision_score(data.iloc[testdata,30],x,average='weighted'))
    confusion.append(confusion_matrix(data.iloc[testdata,30], x))
    scr.append(clf.score(data.iloc[testdata,0:30],data.iloc[testdata,30]))
print(probability)
clf.feature_importances_

with open("C:/Users/deepa/College_Lap_Back/kdd final prj/Results/tree.dot", 'w') as f:
     f = tree.export_graphviz(clf,max_depth=10, out_file=f,feature_names=data.columns[0:30],class_names=["Expensive","Cheap"]) 
tree=clf.tree_
tree.capacity
sumconfusion=sum(confusion)
print('recall=',(float(sumconfusion[0][0])/float((sumconfusion[0][0]+sumconfusion[0][1]))+float(sumconfusion[1][1])/float((sumconfusion[1][1]+sumconfusion[1][0])))/2)
print('precision=' , (sum(precision)/10))
print('scr=' , (sum(scr)/10))
print('score=',(sum(score)/10))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [array([[ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.25925926,  0.74074074],
#        [ 0.21917808,  0.78082192],
#        [ 0.60457029,  0.39542971],
#        [ 0.        ,  1.        ],
#        [ 0.86956522,  0.13043478],
#        [ 0.42666667,  0.57333333],
#        [ 0.60457029,  0.39542971],
#        [ 0.18181818,  0.81818182],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.        ,  1.        ],
#        [ 0.60457029,  0.39542971],
#        [ 0.42666667,  0.57333333],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
#        [ 0.60457029,  0.39542971],
# ...
